# %% [markdown]
#  # 1. Python output

# %%
print("my name is chetan")
# Out:
# my name is chetan

# %%
print("welcome to python programming")
# Out:
# welcome to python programming

# %%
print(100)
# Out:
# 100

# %%
print(3.17)
# Out:
# 3.17

# %%
print("name","Rahul","Age",23)
# Out:
# name Rahul Age 23

# %%
print(10,20,30,40,50,60)
# Out:
# 10 20 30 40 50 60

# %%
print("Chetan","Pratik","Aniket",sep=",")
# Out:
# Chetan,Pratik,Aniket

# %%
print("Chetan","Aniket","Pratik")
# Out:
# Chetan Aniket Pratik

# %%
print("Apple",end=" ")
print("Banana")
# Out:
# Apple Banana

# %%
print("Apple")
print()
print("Orange")
# Out:
# Apple
#
# Orange

# %% [markdown]
# # 2. Python Data Types

# %%
a=10
b=-5
c=0

print(a)
# Out:
# 10

# %%
print(b)
# Out:
# -5

# %%
print(c)
# Out:
# 0

# %%
print(a,b,c)
# Out:
# 10 -5 0

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'int'>

# %%
x = 10.5
y = -15.2
z = 0.0

# %%
print(x,type(x))
print(y,type(y))
print(z,type(z))
# Out:
# 10.5 <class 'float'>
# -15.2 <class 'float'>
# 0.0 <class 'float'>

# %%
name = "Python"
greeting = "Hello"

# %%
print(name,type(name))
# Out:
# Python <class 'str'>

# %%
print(greeting,type(greeting))
# Out:
# Hello <class 'str'>

# %%
Flag_True =True
Flag_False =False

# %%
print(Flag_True,type(Flag_True))
print(Flag_False,type(Flag_False))
# Out:
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# # 3. Variables

# %% [markdown]
# # valid variables

# %%
name = "Chetan"
_age = 23
student1 = "Dhruv"
total_marks = 450

# %%
print(name,_age,student1,total_marks)
# Out:
# Chetan 23 Dhruv 450

# %% [markdown]
# # Multiple Assignment

# %%
x = y = z = 100
print(x,y,z)
# Out:
# 100 100 100

# %% [markdown]
# # Assign Differnt values

# %%
a,b,c = 10,20,30 
print(a,b,c)
# Out:
# 10 20 30

# %%
marks = 85
print(marks)
# Out:
# 85

# %%
marks = 90
print(marks)
# Out:
# 90

# %% [markdown]
# # 4. Comments

# %%
print("Hello") #this is single line commnet
# Out:
# Hello

# %%
'''
this is first line 
this is second line 
this is third line 
'''
print("Python")
# Out:
# Python

# %% [markdown]
# #5. Keyword

# %%
name = "Python"

# %%
print(name)
# Out:
# Python

# %%
import keyword

# %%
keywords = keyword.kwlist

# %%
print(keywords)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# 6. User Input

# %%
# Example : user input

# %%
name = input("Enter your Name: ")
# Out:
# Enter your Name:  Chetan Rajesh Suryawasnhi

# %%
print(name)
# Out:
# Chetan Rajesh Suryawasnhi

# %%
age = input("Enter your current Age: ")
# Out:
# Enter your current Age:  23

# %%
print(age)
# Out:
# 23

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
printO(type(name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 printO(type(name))
#
# NameError: name 'printO' is not defined

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# 7. Type Conversion / Type Casting

# %% [markdown]
# a) implicit Conversion

# %%
a = 10
b = 3.5
c = a + b

# %%
print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# 10 <class 'int'>
# 3.5 <class 'float'>
# 13.5 <class 'float'>

# %% [markdown]
# b) Explicit Conversion

# %%
# String to Integer

# %%
x = "100"
y = int(x)
print(y+50)
# Out:
# 150

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = "150"
y = 50
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 x = "150"
#       2 y = 50
# ----> 3 print(x+y)
#
# TypeError: can only concatenate str (not "int") to str

# %%
 #  integer to float

# %%
a = 25
b = float(a)
print(b)
# Out:
# 25.0

# %%
# # float to integer

# %%
c = 25.22
d = int(c)
print(d)
# Out:
# 25

# %%
 # Number to string

# %%
age = 25
age_str = str(age)
print("Age: "+age_str)
# Out:
# Age: 25

# %% [markdown]
# 8. Escape Sequence

# %%
text1 = "Hello\nWorld"  # New Line Character
print(text1)
# Out:
# Hello
# World

# %%
text2 = "Name:\tChetan"
print(text2)
# Out:
# Name:	Chetan
