# %%
data = [
    (101, "Rahul Rathod", 28, 55000, "Mumbai", "Python,SQL,PySpark", "rahul.rathod@gmail.com", "2022-01-15"),
    (102, "Sachin Patil", 30, 62000, "Pune", "Java,Spring Boot", "sachin.patil@gmail.com", "2021-06-20"),
    (103, "Amit Sharma", 35, 75000, "Delhi", "Python,Azure,ADF", "amit.sharma@gmail.com", "2020-03-10"),
    (104, "Priya Verma", 27, 58000, "Bangalore", "SQL,Power BI", "priya.verma@gmail.com", "2023-02-12"),
    (105, "Neha Singh", 29, 61000, "Hyderabad", "Python,Databricks", "neha.singh@gmail.com", "2021-11-05"),
    (106, "Rohit Gupta", 32, 70000, "Chennai", "Spark,Hadoop", "rohit.gupta@gmail.com", "2019-08-14"),
    (107, "Anjali Mehta", 26, 52000, "Ahmedabad", "SQL,ETL", "anjali.mehta@gmail.com", "2022-09-18"),
    (108, "Vikas Kumar", 34, 80000, "Noida", "AWS,Python", "vikas.kumar@gmail.com", "2018-07-25"),
    (109, "Sneha Joshi", 31, 67000, "Nagpur", "ADF,Synapse", "sneha.joshi@gmail.com", "2020-10-30"),
    (110, "Karan Malhotra", 29, 59000, "Indore", "SQL,MySQL", "karan.malhotra@gmail.com", "2021-04-08"),
    (111, "Pooja Desai", 33, 72000, "Surat", "Python,Pandas", "pooja.desai@gmail.com", "2019-12-15"),
    (112, "Arjun Reddy", 28, 56000, "Vijayawada", "Databricks,Spark", "arjun.reddy@gmail.com", "2022-06-21"),
    (113, "Deepak Yadav", 36, 85000, "Jaipur", "Azure,ADF,Synapse", "deepak.yadav@gmail.com", "2017-05-17"),
    (114, "Kavita Nair", 30, 64000, "Kochi", "SQL,Python", "kavita.nair@gmail.com", "2021-01-11"),
    (115, "Manish Tiwari", 38, 92000, "Lucknow", "Hadoop,Spark", "manish.tiwari@gmail.com", "2016-09-29"),
    (116, "Ritu Sharma", 27, 54000, "Bhopal", "Power BI,Excel", "ritu.sharma@gmail.com", "2023-03-01"),
    (117, "Nitin Jain", 31, 69000, "Chandigarh", "AWS,Databricks", "nitin.jain@gmail.com", "2020-07-07"),
    (118, "Shweta Kulkarni", 29, 61000, "Aurangabad", "Python,SQL", "shweta.kulkarni@gmail.com", "2022-04-19"),
    (119, "Akash Mishra", 35, 78000, "Kanpur", "PySpark,ADF", "akash.mishra@gmail.com", "2019-11-23"),
    (120, "Meera Iyer", 32, 73000, "Coimbatore", "Azure,Python,SQL", "meera.iyer@gmail.com", "2020-02-28")
]

columns = [
    "emp_id",
    "full_name",
    "age",
    "salary",
    "city",
    "skills",
    "email",
    "joining_date"
]

testdf = spark.createDataFrame(data, columns)

# %%
from pyspark.sql.functions import *

# %% [markdown]
# # Date Functions for pyspark

# %%
date = testdf.select(current_date().alias('current_date')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
date = testdf.select(current_timestamp().alias('current_timestamp')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
date = testdf.select(dayofmonth(col("joining_date")).alias('day')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>day</th></tr></thead><tbody><tr><td>15</td></tr><tr><td>20</td></tr><tr><td>10</td></tr><tr><td>12</td></tr><tr><td>5</td></tr><tr><td>14</td></tr><tr><td>18</td></tr><tr><td>25</td></tr><tr><td>30</td></tr><tr><td>8</td></tr><tr><td>15</td></tr><tr><td>21</td></tr><tr><td>17</td></tr><tr><td>11</td></tr><tr><td>29</td></tr><tr><td>1</td></tr><tr><td>7</td></tr><tr><td>19</td></tr><tr><td>23</td></tr><tr><td>28</td></tr></tbody></table></div>

# %%
date = testdf.select(month(col('joining_date')).alias('month')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th></tr></thead><tbody><tr><td>1</td></tr><tr><td>6</td></tr><tr><td>3</td></tr><tr><td>2</td></tr><tr><td>11</td></tr><tr><td>8</td></tr><tr><td>9</td></tr><tr><td>7</td></tr><tr><td>10</td></tr><tr><td>4</td></tr><tr><td>12</td></tr><tr><td>6</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>3</td></tr><tr><td>7</td></tr><tr><td>4</td></tr><tr><td>11</td></tr><tr><td>2</td></tr></tbody></table></div>

# %%
date = testdf.select(year(col('joining_date')).alias('year')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th></tr></thead><tbody><tr><td>2022</td></tr><tr><td>2021</td></tr><tr><td>2020</td></tr><tr><td>2023</td></tr><tr><td>2021</td></tr><tr><td>2019</td></tr><tr><td>2022</td></tr><tr><td>2018</td></tr><tr><td>2020</td></tr><tr><td>2021</td></tr><tr><td>2019</td></tr><tr><td>2022</td></tr><tr><td>2017</td></tr><tr><td>2021</td></tr><tr><td>2016</td></tr><tr><td>2023</td></tr><tr><td>2020</td></tr><tr><td>2022</td></tr><tr><td>2019</td></tr><tr><td>2020</td></tr></tbody></table></div>

# %%
df=spark.createDataFrame([('2026-06-29')],['dates'])

# %%
df.select(to_date('dates').alias('today_date')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>today_date</th></tr></thead><tbody><tr><td>2026-06-29</td></tr></tbody></table></div>

# %%
time_df=spark.createDataFrame([('2026-06-29 14:25:12')],['timestamp_date'])

# %%
time_df.select(to_timestamp('timestamp_date')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>to_timestamp(timestamp_date)</th></tr></thead><tbody><tr><td>2026-06-29T14:25:12.000Z</td></tr></tbody></table></div>

# %%
df.select(date_format(current_date() , "MM-dd-yyyy")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date_format(current_date(), MM-dd-yyyy)</th></tr></thead><tbody><tr><td>06-30-2026</td></tr></tbody></table></div>

# %%
df.select(year((current_date()).alias('current_year'))).display()
df.select(month((current_date()).alias('current_month'))).display()
df.select(dayofmonth((current_date()).alias('current_day'))).display()
df.select(hour(current_timestamp()).alias('current_hour')).display()
df.select(minute(current_timestamp()).alias('current_minute')).display()
df.select(second(current_timestamp()).alias('current_second')).display()
df.select(from_unixtime(unix_timestamp(current_timestamp())).alias('current_timestamp')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year(current_date() AS current_year)</th></tr></thead><tbody><tr><td>2026</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month(current_date() AS current_month)</th></tr></thead><tbody><tr><td>6</td></tr></tbody></table></div>
# ...

# %%
df.select(dayofweek(current_date()).alias('current_dayofweek')).display()

df.select(weekofyear(current_date()).alias('current_weekofyear')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_dayofweek</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_weekofyear</th></tr></thead><tbody><tr><td>27</td></tr></tbody></table></div>

# %%
df.select(months_between(current_date(),date_add(current_date(),365)).alias('months_between')).display()
df.select(months_between(current_date(),date_sub(current_date(),365)).alias('months_between')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>months_between</th></tr></thead><tbody><tr><td>-12.0</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>months_between</th></tr></thead><tbody><tr><td>12.0</td></tr></tbody></table></div>

# %%
df.select(quarter(current_date()).alias('quarter_date')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quarter_date</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

# %%
df.select(date_add(current_date(),30)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date_add(current_date(), 30)</th></tr></thead><tbody><tr><td>2026-07-30</td></tr></tbody></table></div>

# %%
df.select(date_sub(current_date(),40)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date_sub(current_date(), 40)</th></tr></thead><tbody><tr><td>2026-05-21</td></tr></tbody></table></div>

# %%
df.select(add_months(current_date(),1)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add_months(current_date(), 1)</th></tr></thead><tbody><tr><td>2026-07-30</td></tr></tbody></table></div>

# %%
df.select(datediff(lit('2026-06-29'),lit('2026-07-29'))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datediff(2026-06-29, 2026-07-29)</th></tr></thead><tbody><tr><td>-30</td></tr></tbody></table></div>

# %%
df.select(last_day(current_date())).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>last_day(current_date())</th></tr></thead><tbody><tr><td>2026-06-30</td></tr></tbody></table></div>

# %%
df.select(next_day(current_date(),'Mon')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>next_day(current_date(), Mon)</th></tr></thead><tbody><tr><td>2026-07-06</td></tr></tbody></table></div>

# %%
df.select(trunc(current_date(),'month')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trunc(current_date(), month)</th></tr></thead><tbody><tr><td>2026-06-01</td></tr></tbody></table></div>

# %%
df.select(hour(current_timestamp())).display()
df.select(minute(current_timestamp())).display()
df.select(second(current_timestamp())).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hour(current_timestamp())</th></tr></thead><tbody><tr><td>14</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>minute(current_timestamp())</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>
# <style scoped>
# ...
